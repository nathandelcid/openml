# %%
import sys
sys.path.insert(0, '../')

from helpers import show_decision_surface
from mlp_tf import MLP
import sklearn.datasets
import sklearn.metrics
import matplotlib.pyplot as plt

# %%
X, y = sklearn.datasets.make_moons(n_samples=500, noise=0.19, random_state=42) #TODO: Change random_state to the last 5 digits of your BuffOne card
X_train, y_train = X[:350], y[:350]
X_test, y_test = X[350:], y[350:]
plt.title("Two moon clusters (Full dataset)")
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()
